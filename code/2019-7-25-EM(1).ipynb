# %%
import numpy as np
import matplotlib.pyplot as plt
% inline matplotlib

# %%
X1 = 50 * np.random.rand(100, 2) + 50
X2 = 60 * np.random.rand(90, 2) - 60

plt.scatter(X1[:, 0], X1[:, 1])
plt.scatter(X2[:, 0], X2[:, 1])
